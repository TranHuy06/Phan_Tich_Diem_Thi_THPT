# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
df_24 = pd.read_csv('/content/drive/MyDrive/diemthi_thpt_2020_2024/diem_thi_thpt_2024.csv')
df_23 = pd.read_csv('/content/drive/MyDrive/diemthi_thpt_2020_2024/diem_thi_thpt_2023.csv')
df_22 = pd.read_csv('/content/drive/MyDrive/diemthi_thpt_2020_2024/diem_thi_thpt_2022.csv')
df_20_21 = pd.read_csv('/content/drive/MyDrive/diemthi_thpt_2020_2024/diem_thi_2020_2021.csv', low_memory= False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#df_20_21.head()
df_22.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #df_20_21.head()
# ----> 2 df_22.head(10)
#
# NameError: name 'df_22' is not defined

# %%
#print(type(df_20_21))
df_20_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1857877 entries, 870577 to 1795577
# Data columns (total 16 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   SBD        int64
#  1   Tên        object
#  2   Ngày Sinh  object
#  3   Giới tính  object
#  4   Toán       float64
#  5   Văn        float64
#  6   Lý         float64
#  7   Hoá        float64
#  8   Sinh       float64
#  9   Lịch Sử    float64
#  10  Địa Lý     float64
#  11  GDCD       float64
#  12  Ngoại Ngữ  float64
#  13  Year       int64
#  14  code       int64
#  15  province   object
# dtypes: float64(9), int64(3), object(4)
# memory usage: 241.0+ MB

# %%
df_20_21.drop_duplicates(inplace=True)

# %%
df_20_21.duplicated().sum()
# Out:
# 0

# %%
df_20_21.sort_values(by='SBD', ascending=True, inplace = True)
df_20_21.head()
df_22.sort_values(by='SBD', ascending=True, inplace=True)
df_22.head()
df_23.sort_values(by='SBD', ascending=True, inplace=True)
df_23.head()
df_24.sort_values(by='SBD', ascending=True, inplace=True)
df_24.head()
# Out:
#        SBD  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0  1000001   8.4     6.75        8.0     6.0     5.25       5.0      NaN
# 1  1000002   8.6     8.50        7.2     NaN      NaN       NaN     7.25
# 2  1000003   8.2     8.75        8.2     NaN      NaN       NaN     7.25
# 3  1000004   4.8     8.50        7.4     NaN      NaN       NaN     7.00
# 4  1000005   8.6     9.00        7.8     NaN      NaN       NaN     9.00
#
#    dia_li  gdcd ma_ngoai_ngu
# 0     NaN   NaN           N1
# 1    6.00  8.00           N1
# 2    7.25  8.75           N1
# 3    6.00  7.50           N1
# 4    8.75  8.50           N1

# %%
df_24.rename(columns = {'sbd': 'SBD'}, inplace = True)
df_23.rename(columns = {'sbd': 'SBD'}, inplace = True)
df_22.rename(columns = {'sbd': 'SBD'}, inplace = True)
df_20_21.rename(columns = {'sbd': 'SBD'}, inplace = True)

# %%
df_23.drop(columns = 'ma_ngoai_ngu', inplace = True)
df_24.drop(columns = 'ma_ngoai_ngu', inplace = True)

# %%
df_code_province = (df_20_21[['code','province']].drop_duplicates())

# %%
sns.histplot(df_20_21, bins="auto",kde=True)
